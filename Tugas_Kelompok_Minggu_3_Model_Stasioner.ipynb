# %% [markdown]
# <a href="https://colab.research.google.com/github/nadhirahayani/Analisis-Deret-Waktu/blob/main/Tugas_Kelompok_Minggu_3_Model_Stasioner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TUGAS KELOMPOK - MODEL STASIONER**
# ________________________________________________________________________________

# %% [markdown]
# Anggota Kelompok 1:
# 1. Chindy Putri Army (M0501251024)
# 2. Fitri Hayati (M0501251043)
# 3. Nadhira Maulida Hayani (M0501261093
#
# ---

# %% [markdown]
# <h2> TUGAS KELOMPOK </h2>
#
# Masing-masing kelompok gunakan set.seed jumlah 2 digit terakhir NIM semua anggota kelompok.
#
# 1. Buatlah simulasi deret MA (1) dengan panjang pengamatan 20 dengan nilai parameter $\theta=0.1, \theta=0.3, \theta=0.7, \theta=1.0, \theta=1.5, \theta=2.0$
#
# 2. Buatlah plot ACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 1 dan bandingkan. Berdasarkan plot ACF tersebut, apa yang dapat Anda simpulkan terkait nilai autokorelasi pada lag 1 pada model MA(1)? (Hint: Identifikasi pola nilai autokorelasi berdasarkan nilai parameter MA, kaitkan nilai autokorelasi sampel dengan nilai autokorelasi MA(1) secara teori.)
#
# 3. Buatlah simulasi deret MA (1) dengan parameter $\theta=0.25$ dengan panjang pengamatan 60, 100,150, 300.
#
# 4. Buatlah plot ACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 3 dan bandingkan. Berdasarkan plot ACF tersebut apa yang dapat Anda simpulkan terkait nilai autokorelasi pada lag 1 pada model MA(1)? (Hint: Identifikasi pola interval kepercayaan dari nilai autokorelasi berdasarkan panjang observasi.)
#
# 5. Buatlah simulasi deret MA (2) dengan panjang pengamatan 50 dengan parameter:
#
#    a. $\theta_1=0.3, \theta_2=0.8$
#
#    b. $\theta_1=-0.3, \theta_2=0.8$
#
#    c. $\theta_1=0.3, \theta_2=-0.8$
#
#    d. $\theta_1=-0.3, \theta_2=-0.8$
#
# 6. Buatlah plot ACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 5 dan bandingkan. Berdasarkan plot ACF tersebut apa yang dapat Anda simpulkan terkait nilai autokorelasi pada lag 1 dan 2 dari deret MA(2)? (Hint: Identifikasi pola nilai autokorelasi berdasarkan nilai parameter MA.)
#
# 7. Buatlah simulasi deret AR (1) 100 pengamatan dengan nilai parameter $\phi=0.3, \phi=0.9, \phi=-0.3, \phi=-0.9$
#
# 8. Buatlah plot ACF dan PACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 7 dan bandingkan. Berdasarkan plot ACF dan PACF tersebut apa yang dapat Anda simpulkan terkait nilai autokorelasi pada deret AR(1)? (Hint: Identifikasi pola nilai autokorelasi ataupun autokorelasi parsial berdasarkan nilai parameter AR.)
#
# 9. Berdasarkan plot ACF dan PACF pada nomor 8, model apa yang disarankan untuk masing-masing deret? Jelaskan jawaban Anda.
#
# 10. Buatlah simulasi deret AR (2) dengan panjang pengamatan 100 dengan parameter:
#
#    a. $\phi_1=1.5, \phi_2=-0.5$
#
#    b. $\phi_1=0.75, \phi_2=-0.25$
#
#    c. $\phi_1=1, \phi_2=-0.25$
#
#    d. $\phi_1=0.5, \phi_2=-0.75$
#
# 11. Buatlah plot ACF dan PACF dari masing-masing deret hasil simulasi yang Anda peroleh pada nomor 10. Berdasarkan plot ACF dan PACF tersebut apa yang dapat Anda simpulkan terkait nilai autokorelasi pada deret AR(2)? (Hint: Identifikasi pola nilai autokorelasi ataupun autokorelasi parsial berdasarkan nilai parameter AR.)
#
# 12. Berdasarkan plot ACF dan PACF pada nomor 11, model apa yang disarankan untuk masing-masing deret? Jelaskan jawaban Anda.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## MA (1)
#
# Proses MA(1) memiliki persamaan:
#
# <center> $Y_t=e_t-\theta e_{t-1}$ </center>
#
# Membuat simulasi deret MA (1) dengan panjang pengamatan 20 dengan nilai parameter $\theta=0.1, \theta=0.3, \theta=0.7, \theta=1.0, \theta=1.5, \theta=2.0$

# %%
#theta = 0.1
np.random.seed(160)
ar1 = np.array([1])
ma1_theta_01 = np.array([1, -0.1]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli, misal parameter asli 0.1 dalam sintaks ditulis -0.1
ma_object1_theta_01 = ArmaProcess(ar1,ma1_theta_01)
ma1_theta_01= ma_object1_theta_01.generate_sample(nsample=20)
print(ma1_theta_01)
# Out:
# [-0.4967794   0.98770241 -1.60043277 -0.78529106  1.86213422  0.41617824
#  -0.45372793 -1.13734046  1.18924864 -1.01060685 -0.50811523 -0.07037113
#  -1.99260128  2.47606255 -0.39465305 -1.61247077  0.18767941  0.48277637
#   0.26164081  1.34965604]

# %%
#theta = 0.3
np.random.seed(160)
ar1 = np.array([1])
ma1_theta_03 = np.array([1, -0.3]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli, misal parameter asli 0.3 dalam sintaks ditulis -0.3
ma_object1_theta_03 = ArmaProcess(ar1,ma1_theta_03)
ma1_theta_03= ma_object1_theta_03.generate_sample(nsample=20)
print(ma1_theta_03)
# Out:
# [-0.4967794   1.08705829 -1.78803766 -0.48396499  2.04932503  0.06247048
#  -0.57233435 -1.05845551  1.42460522 -1.22492092 -0.32742527  0.04932092
#  -1.96655785  2.87718715 -0.8497531  -1.57905017  0.51351562  0.47782411
#   0.16459031  1.28762283]

# %%
#theta = 0.7
np.random.seed(160)
ar1 = np.array([1])
ma1_theta_07 = np.array([1, -0.7]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli, misal parameter asli 0.7 dalam sintaks ditulis -0.7
ma_object1_theta_07 = ArmaProcess(ar1,ma1_theta_07)
ma1_theta_07= ma_object1_theta_07.generate_sample(nsample=20)
print(ma1_theta_07)
# Out:
# [-0.4967794   1.28577005 -2.16324745  0.11868713  2.42370667 -0.64494504
#  -0.8095472  -0.90068563  1.8953184  -1.65354906  0.03395466  0.288705
#  -1.91447099  3.67943635 -1.7599532  -1.51220896  1.16518805  0.46791959
#  -0.0295107   1.16355641]

# %%
#theta = 1.0
np.random.seed(160)
ar1 = np.array([1])
ma1_theta_10 = np.array([1, -1.0]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli, misal parameter asli 1.0 dalam sintaks ditulis -1.0
ma_object1_theta_10 = ArmaProcess(ar1,ma1_theta_10)
ma1_theta_10= ma_object1_theta_10.generate_sample(nsample=20)
print(ma1_theta_10)
# Out:
# [-0.4967794   1.43480387 -2.44465479  0.57067623  2.7044929  -1.17550669
#  -0.98745684 -0.78235821  2.24835327 -1.97502016  0.30498961  0.46824306
#  -1.87540585  4.28112325 -2.44260328 -1.46207805  1.65394237  0.4604912
#  -0.17508645  1.07050659]

# %%
#theta = 1.5
np.random.seed(160)
ar1 = np.array([1])
ma1_theta_15 = np.array([1, -1.5]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli, misal parameter asli 1.5 dalam sintaks ditulis -1.5
ma_object1_theta_15 = ArmaProcess(ar1,ma1_theta_15)
ma1_theta_15= ma_object1_theta_15.generate_sample(nsample=20)
print(ma1_theta_15)
# Out:
# [-0.4967794   1.68319357 -2.91366702  1.32399139  3.17246994 -2.05977609
#  -1.2839729  -0.58514585  2.83674474 -2.51080534  0.75671451  0.76747317
#  -1.81029727  5.28393475 -3.58035341 -1.37852654  2.46853291  0.44811055
#  -0.4177127   0.91542357]

# %%
#theta = 2.0
np.random.seed(160)
ar1 = np.array([1])
ma1_theta_20 = np.array([1, -2.0]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli, misal parameter asli 2.0 dalam sintaks ditulis -2.0
ma_object1_theta_20 = ArmaProcess(ar1,ma1_theta_20)
ma1_theta_20= ma_object1_theta_20.generate_sample(nsample=20)
print(ma1_theta_20)
# Out:
# [-0.4967794   1.93158328 -3.38267925  2.07730655  3.64044698 -2.94404549
#  -1.58048896 -0.38793349  3.4251362  -3.04659051  1.20843942  1.06670328
#  -1.7451887   6.28674625 -4.71810353 -1.29497502  3.28312344  0.4357299
#  -0.66033895  0.76034054]

# %% [markdown]
#   Membuat plot ACF dari masing-masing deret hasil simulasi yang peroleh pada nomor 1 dan bandingkan. Berdasarkan plot ACF tersebut, apa yang dapat disimpulkan terkait nilai autokorelasi pada lag 1 pada model MA(1)? (Hint: Identifikasi pola nilai autokorelasi berdasarkan nilai parameter MA, kaitkan nilai autokorelasi sampel dengan nilai autokorelasi MA(1) secara teori.)

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt

# Membuat 6 plot dalam 1 frame (3 baris x 2 kolom)
fig, axes = plt.subplots(3, 2, figsize=(12, 12))

# Plot ACF theta = 0.1
plot_acf(ma1_theta_01, lags=10, ax=axes[0, 0])
axes[0, 0].set_title("ACF MA(1), θ = 0.1")

# Plot ACF theta = 0.3
plot_acf(ma1_theta_03, lags=10, ax=axes[0, 1])
axes[0, 1].set_title("ACF MA(1), θ = 0.3")

# Plot ACF theta = 0.7
plot_acf(ma1_theta_07, lags=10, ax=axes[1, 0])
axes[1, 0].set_title("ACF MA(1), θ = 0.7")

# Plot ACF theta = 1.0
plot_acf(ma1_theta_10, lags=10, ax=axes[1, 1])
axes[1, 1].set_title("ACF MA(1), θ = 1.0")

# Plot ACF theta = 1.5
plot_acf(ma1_theta_15, lags=10, ax=axes[2, 0])
axes[2, 0].set_title("ACF MA(1), θ = 1.5")

# Plot ACF theta = 2.0
plot_acf(ma1_theta_20, lags=10, ax=axes[2, 1])
axes[2, 1].set_title("ACF MA(1), θ = 2.0")

# Merapikan jarak antarplot
plt.tight_layout()

plt.show()

# %% [markdown]
# Berdasarkan keenam plot ACF, terlihat bahwa autokorelasi utama pada model MA(1) terdapat pada lag 1, yaitu hubungan antara suatu nilai pengamatan dengan nilai pada satu periode sebelumnya. Sementara itu, nilai autokorelasi pada lag-lag berikutnya cenderung mendekati nol dan sebagian besar berada di dalam interval kepercayaan. Hal ini sesuai dengan karakteristik model MA(1), yaitu ACF secara teori *cut off* setelah lag 1.
#
# Berdasarkan hasil simulasi, nilai autokorelasi pada lag 1 berbeda untuk setiap nilai parameter $\theta$. Secara umum, semakin besar nilai $\theta$ dari 0.1 hingga 1.0, nilai autokorelasi pada lag 1 semakin besar secara absolut. Ketika $\theta$ lebih besar dari 1, yaitu $\theta = 1.5$ dan $\theta = 2.0$, nilai autokorelasi pada lag 1 tidak semakin besar, tetapi cenderung menurun kembali.
#
# Secara teori, untuk model MA(1) dengan bentuk:
#
# $$
# X_t = e_t - \theta e_{t-1},
# $$
#
# nilai autokorelasi pada lag 1 adalah:
#
# $$
# \rho(1) = \frac{-\theta}{1+\theta^2}.
# $$
#
# Berdasarkan rumus tersebut, nilai autokorelasi lag 1 akan bernilai negatif karena pada simulasi digunakan bentuk $X_t = e_t - \theta e_{t-1}$. Nilai absolut autokorelasi meningkat ketika $\theta$ meningkat hingga $\theta = 1$, kemudian menurun ketika $\theta > 1$.
#
# Nilai ACF hasil simulasi tidak sama persis dengan nilai teoritis karena nilai yang diperoleh merupakan autokorelasi sampel dari deret dengan panjang pengamatan hanya 20. Namun, secara umum pola yang diperoleh dapat dibandingkan dengan pola autokorelasi teoritis model MA(1).

# %% [markdown]
# ## MA (1)
#
# Proses MA(1) memiliki persamaan:
#
# <center> $Y_t=e_t-\theta e_{t-1}$ </center>
#
# Membuat simulasi deret MA (1) dengan parameter  θ=0.25  dengan panjang pengamatan 60, 100,150, 300.

# %%
np.random.seed(160)

theta = 0.25
ar1 = np.array([1])
ma1 = np.array([1, -0.25])  # nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma_object1 = ArmaProcess(ar1, ma1)

# Panjang pengamatan 60
MA1_60 = ma_object1.generate_sample(nsample=60)
print("MA(1), theta = 0.25, n = 60")
print(MA1_60)

# Panjang pengamatan 100
MA1_100 = ma_object1.generate_sample(nsample=100)
print("\nMA(1), theta = 0.25, n = 100")
print(MA1_100)

# Panjang pengamatan 150
MA1_150 = ma_object1.generate_sample(nsample=150)
print("\nMA(1), theta = 0.25, n = 150")
print(MA1_150)

# Panjang pengamatan 300
MA1_300 = ma_object1.generate_sample(nsample=300)
print("\nMA(1), theta = 0.25, n = 300")
print(MA1_300)
# Out:
# MA(1), theta = 0.25, n = 60
# [-0.4967794   1.06221932 -1.74113644 -0.55929651  2.00252733  0.15089742
#  -0.54268275 -1.07817675  1.36576608 -1.17134241 -0.37259776  0.0193979
#  -1.97306871  2.776906   -0.73597809 -1.58740532  0.43205657  0.47906218
#   0.18885293  1.30313114 -1.6650652   1.97991618  1.48404804  0.45556765
#  -0.40863443 -1.23605613  0.17512584  1.14635558 -1.39905108  0.73598823
#  -0.44233366 -1.66154072  1.27882476  0.7082918  -0.92117614  0.30532399
#  -0.79701421  1.38990911 -1.35831451 -0.81309955  0.28944162  0.33671201
#   1.43150059 -0.68907794  0.89691489 -0.29785698  0.09369604  0.48931065
#  -1.16194208  0.70860124 -0.50535246 -0.41781456  0.54241593 -1.09386923
#  -0.71569098 -0.07157913  1.64775315 -2.00480587  2.35184764  0.39492364]
#
# MA(1), theta = 0.25, n = 100
# [ 0.1238974   0.43167308  0.36582023  1.46219865  0.42226388  0.25789975
#  -0.85847712 -0.74857057  0.88808207 -1.05351165 -0.46664518  1.27809613
#  -0.28222889 -0.6400752  -1.02110991  1.14355779  0.28535498  0.60632384
#   1.43386637 -0.48101841 -0.97460582  0.86803598 -0.37852472 -2.26887205
#   2.07443597  1.40328964 -0.3859961   1.60278939 -0.48126967 -1.11359859
#  -1.92493723  1.19848683 -0.31966927  0.4103209   0.74344958  1.21421196
#   0.67460879 -0.00415898 -0.22902599 -0.43296279 -0.08265051 -0.11947982
#   1.10513459 -2.4163885  -0.11277082  0.038216   -0.52387697 -0.86449182
#   0.40463233 -0.77350558  0.70489143  1.08571246  0.27591379 -0.52319225
#  -0.56053885 -0.30979508  0.21091793  1.53463956 -1.45155887 -0.00255284
#  -0.52534222 -0.46006567  1.47753604 -1.00160902  0.69689447  0.48456644
#  -0.48925702  1.04376194  0.46101605 -0.99071055  1.31773725 -0.89038405
#  -0.45057988  1.41390363 -0.76342269 -0.86218815  1.67091971 -1.24627917
#  -0.22833753  1.45953972 -1.85682731 -1.04736884  1.06725971  0.18858547
#   0.17693588 -1.39887758 -1.80746179  0.55644136 -0.46478462 -1.31087969
#   1.22550481  0.16946172  1.4008218   0.07427823 -1.28921119  1.71140959
#   0.84928522  0.80635893 -0.28063461 -0.58596357]
#
# MA(1), theta = 0.25, n = 150
# [ 0.56860765 -0.24126289  0.24467283 -0.01638395 -2.07296775  1.26556635
#   0.06673083 -0.38160978  0.16260599  1.46106121  1.02204088  1.37752461
#   0.49694963  0.79986532 -0.13386699  0.68508697  1.53249882 -2.01236589
#  -1.02738977  0.62781626  0.98966375  0.46621938  0.37563793  0.18352216
#  -0.15726916 -0.74995649  0.8388672   0.43221335  0.91455107 -0.74070749
#  -0.33379267 -1.09606704  1.91506608  0.04286014 -0.30445915  0.18364412
#  -0.6197532   0.89496281 -1.41424533  0.37256787  0.43681544 -0.86713696
#  -0.43039471  0.17499525  0.00463342 -1.34648963  0.42279675 -1.47125114
#   0.35608938  1.13769321  1.04605686  0.52696395  0.85894242 -0.86278745
#   1.70398201 -0.98137626  0.20362334 -1.50511343  1.13214726 -1.17943851
#  -0.29095913 -0.64141029 -1.04174876  0.36996095 -1.35290942  0.21696195
#  -0.08214495 -0.46972309  0.10613554  0.80662784 -0.04725928 -0.07805262
#  -1.12487543  1.34029195 -0.48853327 -1.13655081  0.07853009 -2.23569365
#   0.97698117  0.33367205 -0.29944589  0.69819507  0.59811235  0.27843975
#   0.71780059  0.01335909 -0.5399458  -0.08955738 -0.01491962  0.42907325
#  -0.94975618 -0.08804895 -2.2210454   2.15732677 -1.98134677 -0.13999923
#  -0.04368387  0.42167745  0.80159599 -1.92490638 -0.24259591  0.49796447
#  -1.60019424 -0.71394297  0.08565932 -2.00285129  0.38435226 -1.08171473
#   0.31140504  0.21445372  0.49894197  1.55734242 -0.82679199  0.54365217
#  -0.18741307  0.69570656  0.30677847 -2.14517428  1.1300341  -0.36221366
#   0.90998573  1.53862648  0.66389058  0.17958403 -1.93220423  0.9090782
#   0.81714905  0.27363738 -0.56381743  1.44784393 -1.00201699  1.24687916
#  -1.05704247  0.45195305 -1.49711482  1.22974206  1.04479416 -0.09012279
#  -1.08488259  0.38416253  2.38598615 -0.63822067 -0.89099467  0.7787492
#  -0.33574242  1.61517092  0.2137485   0.55324424  0.11838979  1.71546451]
#
# MA(1), theta = 0.25, n = 300
# [ 9.74285259e-01 -2.52118178e-01  9.31842149e-01  2.54419461e-01
#  -3.94258513e-01  5.14601082e-01  9.70466666e-01 -8.17221570e-02
#   1.43203174e+00  4.91843978e-02  8.87830522e-01  8.14483944e-01
#  -1.24928846e-01 -1.74519901e+00 -1.13748594e+00  2.02776387e+00
#   4.88956818e-01 -1.75722670e+00  1.65457757e+00 -9.89339708e-01
#   2.74381071e+00 -1.02083309e+00 -1.29465471e+00 -2.50533564e+00
#   4.82121635e-01  7.82669505e-02 -2.60027921e-01 -8.56938559e-01
#  -6.33590688e-01  2.25644689e+00 -1.06463769e+00 -2.82144214e-01
#   9.22629327e-01 -2.31206789e-01 -9.09506945e-01  2.03047066e+00
#  -1.28546463e+00  1.70322536e+00 -1.08475809e+00  8.22254780e-01
#   2.30574684e-01 -1.86850718e+00  1.19122706e+00 -6.66866849e-01
#   2.04566422e+00 -1.23042767e+00  1.32312298e+00  8.72371394e-01
#  -2.05054991e+00  1.63840309e+00  4.76578005e-01 -1.07160039e+00
#   6.25788029e-02  1.03558439e+00 -9.53537361e-02 -2.07241681e-01
#   4.23904175e-02 -1.09296228e+00  6.23190040e-01 -1.35289434e+00
#   1.40068076e+00 -1.52346946e-01  2.11181719e+00 -5.04326367e-01
#   3.76024367e-01 -5.26684759e-02 -3.79609347e-01 -9.87254144e-02
#  -3.80801024e-01 -1.89956292e-01 -7.33830164e-03 -1.58744388e+00
#  -1.09846066e+00  8.79791404e-01  4.16805204e-01  1.24193754e+00
#  -8.17823411e-01 -6.82757310e-01  1.71084440e+00 -2.96635210e-01
#  -1.00810973e-01 -1.06849456e+00  1.10258522e+00  1.63459849e+00
#  -1.15641859e+00  1.78159184e+00 -3.97167929e-01 -9.39316149e-01
#   5.07830213e-01  5.44674407e-01 -1.14812038e+00  2.21400167e-01
#  -8.63419984e-02  4.65357193e-01 -6.80977795e-02 -1.42098888e+00
#   3.71956884e-01  7.37782168e-04 -7.09162284e-01  1.02361317e+00
#   1.75078199e+00 -1.20228458e+00  7.38899543e-01  5.83739610e-01
#   8.67780054e-01 -8.11113109e-01 -6.31266938e-01  1.50416244e+00
#   1.23104418e+00 -3.74412069e-01  4.61290439e-01  1.70424049e+00
#  -2.12033620e+00  2.17251323e-03  7.11995252e-01  1.13102536e+00
#  -1.89025529e+00 -4.23325504e-01 -4.51403436e-01 -1.04166341e+00
#   1.65432049e+00 -1.87789444e-01  1.20750624e+00  1.44410359e-01
#  -4.08616448e-01  5.52423312e-01 -1.14770068e-01  1.03969273e-01
#  -3.08179272e+00  9.35661818e-01 -1.07493412e+00  1.90637113e+00
#  -5.96723596e-01 -1.61429614e+00  1.87038144e+00 -1.48234896e+00
#   1.07329288e+00  1.65211536e-01 -1.40978094e+00 -1.28516398e-02
#   7.13715885e-01 -9.53504923e-01  4.15565577e-01  1.12105392e-01
#   5.18515616e-01  6.46110282e-01  4.01246941e-01 -5.89963143e-01
#  -3.66831309e-01  1.21259971e+00  7.17491571e-02 -2.29278503e-01
#  -1.12364157e+00  9.71870779e-01 -6.33778273e-01  1.31231875e+00
#   8.38703912e-02 -2.18915812e-01  1.20677523e+00  1.21697437e+00
#  -9.68415718e-01  2.29821639e+00 -6.77904616e-01  1.09861549e+00
#  -8.95695180e-01  1.52684823e+00  5.37807620e-01  1.67988007e-01
#  -1.38129926e+00  7.36971112e-02  1.61819541e+00  7.26507090e-01
#   1.18545044e+00  6.17763887e-01  9.64863263e-01  1.18189984e+00
#   1.58229681e+00  3.69319435e-01 -5.31185647e-01 -4.09475215e-01
#   1.46775965e-01 -1.07112356e+00 -7.76579254e-01  5.95336321e-01
#   3.19340452e-01 -1.41884081e+00 -4.28751261e-01 -2.40482289e-01
#  -8.00415882e-01 -1.30201947e+00  1.56706724e+00 -6.88430832e-01
#  -4.21425855e-01 -1.79242855e+00  3.74618565e-01 -3.74687487e-01
#  -9.29612335e-01 -1.11138430e+00 -3.85782076e-01 -2.19614445e-01
#   6.61463656e-01 -9.99450928e-01  1.35761312e+00 -1.39353318e-01
#  -1.44232478e+00  4.37766936e-01  1.58942763e+00 -8.37807247e-01
#  -5.49083496e-01  1.86653439e+00 -8.80157943e-01  1.07165821e-01
#  -1.31713456e+00  2.99171065e+00  3.36434009e-01  4.77864177e-01
#   8.46383814e-01  3.27151016e-01 -1.39475202e+00  1.43540508e+00
#   1.10322155e+00  5.33240971e-01  9.89286711e-02  1.02952147e-01
#  -2.12002485e-01 -3.31679367e-01  5.50754067e-01 -1.27060581e+00
#   1.26703220e+00 -8.44590523e-01  5.16632820e-01  6.10765132e-01
#  -1.81162911e+00  2.16157331e+00  1.12002097e+00 -1.79960534e+00
#   3.64168878e-01 -1.05166031e+00 -1.99574543e+00  1.17227833e+00
#  -2.78894645e-01 -5.29568969e-01 -2.82420308e+00  7.15619875e-01
#  -5.74764857e-01 -1.42214787e-01 -2.20655407e-01  9.30764944e-02
#   6.19168701e-01 -1.60515615e+00 -9.73976964e-01 -1.30948204e+00
#  -5.98307833e-01 -2.41505318e-02 -6.82990569e-01  1.50784951e+00
#  -1.92325338e-01  1.23759462e+00 -1.43486962e+00  9.63753875e-01
#  -1.93867946e+00  7.39435170e-01 -1.43214998e+00  1.17996300e-01
#   3.86202128e-01 -5.71640738e-01 -7.15845303e-01  2.20920473e-02
#   1.59928268e+00 -1.49197850e+00  8.97562474e-01 -3.16374403e-01
#   1.43695683e+00  2.34355683e-01 -1.74112797e+00  2.32224843e-01
#   1.06204914e+00 -1.52576811e+00 -3.09098844e-01 -5.60555258e-02
#  -2.03901970e-01 -2.30804054e-01  5.83915563e-01 -8.85509434e-01
#   2.82145238e-01  1.15202532e+00 -5.48248506e-02 -7.79988728e-01
#   3.63425947e-01 -3.91415792e-01  1.48577144e-01 -5.75476681e-01
#   9.31724650e-01  1.65453110e-01 -6.83797041e-01  1.61826931e+00
#  -3.83701994e-01 -4.84593877e-01 -4.96052189e-01 -4.30232067e-01]

# %% [markdown]
# Membuat plot ACF dari masing-masing deret hasil simulasi yang peroleh pada nomor 3 dan membandingkannya. Berdasarkan plot ACF tersebut apa yang dapat disimpulkan terkait nilai autokorelasi pada lag 1 pada model MA(1)? (Hint: Identifikasi pola interval kepercayaan dari nilai autokorelasi berdasarkan panjang observasi.

# %%
# ACF untuk n = 60
plt.figure()
plot_acf(MA1_60, zero=False)
plt.title('ACF MA(1) dengan θ = 0.25, n = 60')
plt.show()

# %%
#ACF untuk n = 100
plt.figure()
plot_acf(MA1_100, zero=False)
plt.title('ACF MA(1) dengan θ = 0.25, n = 100')
plt.show()

# %%
#ACF untuk n = 150
plt.figure()
plot_acf(MA1_150, zero=False)
plt.title('ACF MA(1) dengan θ = 0.25, n = 150')
plt.show()

# %%
# ACF untuk n = 300
plt.figure()
plot_acf(MA1_300, zero=False)
plt.title('ACF MA(1) dengan θ = 0.25, n = 300')
plt.show()

# %% [markdown]
# Berdasarkan plot ACF dari keempat deret hasil simulasi MA(1) dengan θ=0,25, terlihat bahwa autokorelasi yang paling jelas terdapat pada lag 1, sedangkan pada lag berikutnya cenderung berada di sekitar nol. Pola ini sesuai dengan karakteristik model MA(1).
#
# Model yang digunakan adalah
#
# $$ X_t=\varepsilon_t-\theta\varepsilon_{t-1}, $$
#
# sehingga ACF teoritis pada lag 1 adalah
#
# $$ \rho(1)=-\frac{\theta}{1+\theta^2}. $$
#
# Dengan θ=0,25,
#
# $$ \rho(1) =-\frac{0{,}25}{1+(0{,}25)^2} \approx -0{,}235. $$
#
# Sementara itu, untuk lag \(k>1\),
#
# $$ \rho(k)=0. $$
#
# Dengan demikian, secara teoritis ACF MA(1) akan terputus (cut-off) setelah lag 1. Nilai ACF lag 1 pada hasil simulasi tidak harus tepat -0.235 karena merupakan ACF sampel yang dipengaruhi oleh variasi acak.
#
# Dari keempat plot juga terlihat bahwa semakin besar panjang observasi, interval kepercayaan semakin sempit. Secara pendekatan, interval kepercayaan 95% ACF dapat dituliskan sebagai
#
# $$ \pm\frac{1{,}96}{\sqrt{n}}. $$
#
# Untuk \(n=60,100,150,\) dan \(300\), batas intervalnya berturut-turut sekitar
#
# $$ \pm0{,}253,\quad \pm0{,}196,\quad \pm0{,}160,\quad \pm0{,}113. $$
#
# Hal ini menunjukkan bahwa semakin banyak observasi, estimasi ACF menjadi semakin presisi. Oleh karena itu, pada \(n=300\) pola autokorelasi pada lag 1 lebih mudah terlihat dibandingkan \(n=60\).

# %% [markdown]
# ## MA (2)
#
# Proses MA (2) memiliki persamaan:
#
# <center> $Y_t=e_t-\theta_1 e_{t-1}-\theta_2 e_{t-2}$ </center>
#
# Membuat simulasi deret MA (2) dengan panjang pengamatan 50 dengan parameter:
#
# a. $\theta_1=0.3, \theta_2=0.8$
#
# b. $\theta_1=-0.3, \theta_2=0.8$
#
# c. $\theta_1=0.3, \theta_2=-0.8$
#
# d. $\theta_1=-0.3, \theta_2=-0.8$

# %% [markdown]
# 5a. deret MA(2) dengan 50 pengamatan dengan parameter $\theta_1=0.3, \theta_2=0.8$

# %%
# a. θ1=0.3,θ2=0.8
np.random.seed(160)
ar1_a = np.array([1])
ma1_a = np.array([1, -0.3, -0.8]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma_object2_a = ArmaProcess(ar1_a,ma1_a)
ma2_a = ma_object2_a.generate_sample(nsample=50)

# %%
plot_acf(ma2_a, zero=False)
plt.title(r'ACF MA(2), $\theta_1=0.3,\ \theta_2=0.8$')
plt.show()

# %% [markdown]
# 5b. deret MA(2) dengan 50 pengamatan dengan parameter $\theta_1=-0.3, \theta_2=0.8$

# %%
# b. θ1=−0.3,θ2=0.8
np.random.seed(160)
ar1_b = np.array([1])
ma1_b = np.array([1, 0.3, -0.8]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma_object2_b = ArmaProcess(ar1_b,ma1_b)
ma2_b = ma_object2_b.generate_sample(nsample=50)

# %%
plot_acf(ma2_b, zero=False)
plt.title(r'ACF MA(2), $\theta_1=-0.3,\ \theta_2=0.8$')
plt.show()

# %% [markdown]
# 5c. deret MA(2) dengan 50 pengamatan dengan parameter $\theta_1=0.3, \theta_2=-0.8$

# %%
# c. θ1=0.3,θ2=−0.8
np.random.seed(160)
ar1_c = np.array([1])
ma1_c = np.array([1, -0.3, 0.8]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma_object2_c = ArmaProcess(ar1_c,ma1_c)
ma2_c = ma_object2_c.generate_sample(nsample=50)

# %%
plot_acf(ma2_c, zero=False)
plt.title(r'ACF MA(2), $\theta_1=0.3,\ \theta_2=-0.8$')
plt.show()

# %% [markdown]
# 5d. deret MA(2) dengan 50 pengamatan dengan parameter $\theta_1=-0.3, \theta_2=-0.8$

# %%
np.random.seed(160)
ar1_d = np.array([1])
ma1_d = np.array([1, 0.3, 0.8]) #nilai parameter theta dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma_object2_d = ArmaProcess(ar1_d,ma1_d)
ma2_d = ma_object2_d.generate_sample(nsample=50)

# %%
plot_acf(ma2_d, zero=False)
plt.title(r'ACF MA(2), $\theta_1=-0.3,\ \theta_2=-0.8$')
plt.show()

# %% [markdown]
# Membuat plot ACF dari masing-masing deret hasil simulasi yang peroleh pada nomor 5 dan bandingkan. Berdasarkan plot ACF tersebut apa yang dapat disimpulkan terkait nilai autokorelasi pada lag 1 dan 2 dari deret MA(2)? (Hint: Identifikasi pola nilai autokorelasi berdasarkan nilai parameter MA.)

# %% [markdown]
# Berdasarkan hasil simulasi deret MA(2) dengan panjang pengamatan $n=50$ untuk empat kombinasi parameter $\theta_1$ dan $\theta_2$ ($\pm0,3$ dan $\pm0,8$), diperoleh nilai autokorelasi sampel dan teori sebagai berikut:
#
# - (a) $\theta_1=0,3$, $\theta_2=0,8$:
#   - $\rho_1$ sampel $=-0,125$ (teori $\approx-0,035$)
#   - $\rho_2$ sampel $=-0,51$ (teori $\approx-0,462$)
# - (b) $\theta_1=-0,3$, $\theta_2=0,8$:
#   - $\rho_1$ sampel $=-0,09$ (teori $\approx0,035$)
#   - $\rho_2$ sampel $=-0,53$ (teori $\approx-0,462$)
# - (c) $\theta_1=0,3$, $\theta_2=-0,8$:
#   - $\rho_1$ sampel $=-0,51$ (teori $\approx-0,312$)
#   - $\rho_2$ sampel $=0,29$ (teori $\approx0,462$)
# - (d) $\theta_1=-0,3$, $\theta_2=-0,8$:
#   - $\rho_1$ sampel $=0,51$ (teori $\approx0,312$)
#   - $\rho_2$ sampel $=0,26$ (teori $\approx0,462$)
#
# Nilai $\rho_2$ pada seluruh kombinasi konsisten mengikuti tanda $\theta_2$, $\theta_2$ positif menghasilkan $\rho_2$ negatif, dan sebaliknya, tanpa dipengaruhi oleh tanda $\theta_1$, sedangkan nilai $\rho_1$ ditentukan oleh interaksi keduanya: ketika $\theta_1$ dan $\theta_2$ berlawanan tanda (kasus a dan b), kedua suku pada persamaan $\rho_1$ saling meniadakan sehingga nilainya kecil dan mendekati nol, sedangkan ketika keduanya bertanda sama (kasus c dan d), kedua suku saling menguatkan sehingga $\rho_1$ menjadi lebih besar.
#
# Meskipun terdapat sejumlah selisih antara nilai sampel dan nilai teori, hal tersebut wajar karena panjang pengamatan yang digunakan terbatas $n=50.$ Tanda autokorelasi pada kedua lag umumnya konsisten dengan hasil teoretis, sehingga hasil simulasi dapat dikatakan mendukung persamaan $\rho_1$ dan $\rho_2$ pada model MA(2). Selain itu, dari plot ACF juga terlihat bahwa nilai autokorelasi pada lag ketiga dan seterusnya berada di dalam selang kepercayaan, sesuai dengan sifat *cut-off* MA(2) yang menyatakan $\rho_k=0$ untuk $k\geq3$.

# %% [markdown]
# <h1> Regresi Diri (Autoregressive) </h1>
#
# Secara spesifik, proses autoregressive order p dari deret ${Y_t}$ memenuhi persamaan berikut:
#
# <center> $Y_t=\phi_1 Y_{t-1}+\phi_2 Y_{t-2}+...+\phi_p Y_{t-p}+e_t$ </center>
#
# Nilai $Y_t$ pada waktu sekarang merupakan kombinasi linier dari sebanyak p nilai $Y_t$ pada waktu lampau ditambah $e_t$ yang saling bebas terhadap $Y_{t-1}, Y_{t-2},...$.
#
#
# <h2> AR (1) </h2>
#
# Proses AR (1) memiliki persamaan:
#
# <center> $Y_t=\phi Y_{t-1}+e_t$ </center>
#
# **Syarat kestasioneran untuk deret AR (1) adalah jika dan hanya jika $|\phi|<1$.**
#
# Membuat simulasikan deret AR (1) 100 pengamatan dengan nilai parameter $\phi=0.3$, $\phi=0.9$, $\phi=-0.3$, $\phi=-0.9$

# %%
# AR(1) dengan φ = 0.3
np.random.seed(160)
#phi=0.3
ar1 = np.array([1,-0.3]) # nilai parameter phi dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma1 = np.array([1])
ar_object1 = ArmaProcess(ar1,ma1)
AR1_03 = ar_object1.generate_sample(nsample=100)

# %%
# AR(1) dengan φ = 0.9
np.random.seed(160)
# phi=0.9
ar1 = np.array([1,-0.9]) # nilai parameter phi dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma1 = np.array([1])
ar_object1 = ArmaProcess(ar1,ma1)
AR1_09 = ar_object1.generate_sample(nsample=100)

# %%
#AR(1) dengan φ = −0.3
np.random.seed(160)
# phi=-0.3
ar1 = np.array([1,0.3]) # nilai parameter phi dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma1 = np.array([1])
ar_object1 = ArmaProcess(ar1,ma1)
AR1_min03 = ar_object1.generate_sample(nsample=100)

# %%
#AR(1) dengan φ = −0.9
np.random.seed(160)
# phi=-0.9
ar1 = np.array([1,0.9]) # nilai parameter phi dalam sintaks dituliskan sebagai negatif dari nilai parameter asli
ma1 = np.array([1])
ar_object1 = ArmaProcess(ar1,ma1)
AR1_min09 = ar_object1.generate_sample(nsample=100)

# %% [markdown]
# Membuat plot ACF dan PACF dari masing-masing deret hasil simulasi yang peroleh pada nomor 7 dan membandingkannya. Berdasarkan plot ACF dan PACF tersebut apa yang dapat disimpulkan terkait nilai autokorelasi pada deret AR(1)? (Hint: Identifikasi pola nilai autokorelasi ataupun autokorelasi parsial berdasarkan nilai parameter AR.)

# %%
# ACF AR(1) dengan φ = 0.3
plt.figure()
plot_acf(AR1_03, zero=False)
plt.title('ACF AR(1) dengan φ = 0.3')
plt.show()

# %%
# PACF AR(1) dengan φ = 0.3
plt.figure()
plot_pacf(AR1_03, zero=False)
plt.title('PACF AR(1) dengan φ = 0.3')
plt.show()

# %%
# ACF AR(1) dengan φ = 0.9
plt.figure()
plot_acf(AR1_09, zero=False)
plt.title('ACF AR(1) dengan φ = 0.9')
plt.show()

# %%
#PACF AR(1) dengan φ = 0.9
plt.figure()
plot_pacf(AR1_09, zero=False)
plt.title('PACF AR(1) dengan φ = 0.9')
plt.show()

# %%
# ACF AR(1) dengan φ = -0.3
plt.figure()
plot_acf(AR1_min03, zero=False)
plt.title('ACF AR(1) dengan φ = -0.3')
plt.show()

# %%
# PACF AR(1) dengan φ = -0.3
plt.figure()
plot_pacf(AR1_min03, zero=False)
plt.title('PACF AR(1) dengan φ = -0.3')
plt.show()

# %%
#ACF AR(1) dengan φ = -0.9
plt.figure()
plot_acf(AR1_min09, zero=False)
plt.title('ACF AR(1) dengan φ = -0.9')
plt.show()

# %%
# PACF AR(1) dengan φ = -0.9
plt.figure()
plot_pacf(AR1_min09, zero=False)
plt.title('PACF AR(1) dengan φ = -0.9')
plt.show()

# %% [markdown]
# Berdasarkan plot ACF dan PACF dari masing-masing deret AR(1), terlihat bahwa nilai parameter φ memengaruhi pola autokorelasi. Pada φ = 0,3 dan φ = 0,9, nilai ACF cenderung positif dan menurun secara bertahap. Semakin besar nilai φ, autokorelasi semakin kuat dan penurunannya semakin lambat. Sebaliknya, pada φ = −0,3 dan φ = −0,9, nilai ACF menunjukkan pola autokorelasi yang berganti tanda antara positif dan negatif. Pola tersebut lebih kuat pada φ = −0,9.
#
# Pada plot PACF, autokorelasi parsial paling jelas terlihat pada lag 1, sedangkan pada lag berikutnya sebagian besar nilai berada dalam interval kepercayaan atau mendekati nol. Hal ini menunjukkan karakteristik dari model AR(1), yaitu pengaruh langsung terutama terdapat pada lag 1.
#
# Jadi, nilai dan tanda parameter φ menentukan pola autokorelasi pada ACF. Semakin besar nilai absolut φ, semakin kuat ketergantungan antar-pengamatan. Sementara itu, PACF pada AR(1) terputus setelah lag 1.

# %% [markdown]
# ---
# Berdasarkan plot ACF dan PACF pada nomor 8, model apa yang disarankan untuk masing-masing deret? Jelaskan jawaban Anda.
#
# **Jawaban:**
# Berdasarkan plot ACF dan PACF pada nomor 8, model yang disarankan untuk keempat deret adalah AR(1). Hal ini ditunjukkan oleh pola ACF yang menurun secara bertahap, sedangkan PACF menunjukkan autokorelasi parsial yang paling jelas pada lag 1 dan kemudian cenderung mendekati nol. Pada deret dengan φ positif, ACF cenderung bernilai positif dan menurun secara bertahap, sedangkan pada φ negatif ACF menunjukkan pola berganti tanda antara positif dan negatif. Semakin besar nilai absolut φ, semakin kuat dan semakin lama pola autokorelasi terlihat. Oleh karena itu, karakteristik ACF dan PACF tersebut mendukung penggunaan model AR(1) untuk masing-masing deret.

# %% [markdown]
# <h2> AR (2) </h2>
#
# Proses AR (2) memiliki persamaan:
#
# <center> $Y_t=\phi_1 Y_{t-1}+\phi_2 Y_{t-2}+e_t$ </center>
#
# **Syarat kestasioneran untuk deret AR (2) adalah jika dan hanya jika tiga kondisi berikut terpenuhi, yaitu:**
#
# **<center> $\phi_1+\phi_2<1$  ,   $\phi_2-\phi_1<1$ ,   $|\phi_2|<1$ </center>**
#
# Membuat simulasikan deret AR (2) dengan panjang pengamatan 100 dengan parameter:
# a. $\phi_1=1.5, \phi_2=-0.5$
#
#    b. $\phi_1=0.75, \phi_2=-0.25$
#
#    c. $\phi_1=1, \phi_2=-0.25$
#
#    d. $\phi_1=0.5, \phi_2=-0.75$

# %%
# AR(2) Bagian A
# psi1 = 1.5 dan psi2 = -0.5
np.random.seed(160)
psi1, psi2= 1.5,-0.5

ar2_a = [np.random.uniform(0,1),
     np.random.uniform(0,1)]
for i in range(98):
    ar2_a.append(psi1*ar2_a[i+1]+
               psi2*ar2_a[i]+
               np.random.normal(0,1))
print(ar2_a)
# Out:
# [0.8333928248007452, 0.32343457490346217, -1.43817486865349, -3.254933678666267, -2.3947742756933375, -1.3716624529910948, -1.2545312594955829, -2.372748591367712, -1.860286911965622, -2.507505890984641, -3.4295755936019243, -4.020827593835959, -6.3220765905398775, -5.197200835350917, -4.801865982802775, -6.233379629157166, -6.924375152835832, -6.784620412255485, -6.4045769859364965, -4.833882623069857, -5.3684324770586125, -3.9857654856672537, -1.3978984706831643, 0.825736062624692, 1.761344157051001, 0.9490397804649418, 0.39798632824418045, 1.2325898710166576, 0.5283731322905068, 0.6318733638142595, 0.3551919713933762, -1.526797323122979, -1.6248793558294112, -0.754900419933566, -1.0113321017676618, -1.007079239480255, -1.7688498464201174, -0.950800303764481, -1.6003563298793106, -3.0028790902799707, -3.6841350351833952, -3.6830496407141373, -2.1655780075450446, -1.716687897314647, -0.6727893823187537, -0.2438337436658598, 0.04109171041928372, 0.6904769998718856, -0.020041796425750213, 0.07449718344193035, -0.27113619631883623, -0.9599931621549416, -0.8910157810186371, -1.8470448521112295, -3.2883798125135444, -4.321456529061264, -3.268344048267174, -4.3541809662044955, -2.94835007932199, -1.3633236594745641, -0.4469130509734688, 0.473939680695404, 1.415848134609828, 3.4693715373017904, 5.314039411569369, 6.698749642694647, 6.64822171351728, 5.688666420853562, 5.863398013304363, 5.060879472368316, 3.9705039347695963, 4.531133229308345, 4.805673247967597, 4.3014243988067635, 2.8678103473343137, 2.999188701171988, 3.562279207103547, 4.574498631705106, 6.6971432562972435, 7.681580888083179, 7.179972711955152, 7.548747854371363, 7.50950551567491, 5.1651048230924586, 5.486145562662662, 7.4232658439817065, 8.449979867049365, 10.580664743925029, 11.569069483361291, 10.930438842863644, 8.402978040699812, 7.7856980993392915, 7.3190014715282, 7.456459896401927, 8.361340369835471, 10.23703038426458, 12.205296628578514, 13.44287608265407, 13.8960014039838, 13.648185177829406]

# %%
plt.figure(figsize=(10,5))
plt.plot(ar2_a,'-o')
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
# AR(2) Bagian B
# psi1 = 0.75 dan psi2 = -0.25
np.random.seed(160)
psi1, psi2= 0.75,-0.25

ar2_b = [np.random.uniform(0,1),
     np.random.uniform(0,1)]
for i in range(98):
    ar2_b.append(psi1*ar2_b[i+1]+
               psi2*ar2_b[i]+
               np.random.normal(0,1))
print(ar2_b)
# Out:
# [0.8333928248007452, 0.32343457490346217, -1.4724025936309004, -2.121114677183342, 0.5458034484995362, 1.5326633768862654, 0.6186219526842055, -1.0959823083282973, 0.09492812592088096, -0.5582581471973287, -1.0408858549859905, -0.7713170033655536, -2.323889285364569, 0.7254125403588805, 0.9579287015639637, -1.0920876815452085, -1.0337866370513695, -0.01706555498254475, 0.5558135490547491, 1.8017992002438428, -0.10750102250288118, 1.1188663514476151, 2.7625585384998415, 2.721903341828789, 1.1745786995190122, -1.0796502346171515, -1.2482836147703484, 0.4438301164593843, -0.4765750190752639, -0.012780192534465717, -0.218872897814793, -1.9046082235333919, -0.5308253286446003, 0.9970530116489589, 0.18907494111585066, 0.025011656129103027, -0.7924070312657013, 0.5983766586440158, -0.4116965456432108, -1.5361113212366577, -1.0291539192197854, -0.04612424218470412, 1.7396242341008816, 1.0064035297676883, 1.1393500486812407, 0.5099180352239557, 0.16804864900635325, 0.505479540358806, -0.6981139480064206, -0.20015696807801842, -0.3684921087515155, -0.7423701154998541, -0.05124869538265453, -0.843361754322772, -1.583029566752434, -1.2888409728301935, 0.9987775011334123, -0.5410997892767582, 1.2932301286102446, 1.9873085201830456, 1.2910712565621054, 0.9341237397941426, 0.8593070787850681, 1.993518549875016, 2.0982183156315917, 1.5376603932464281, -0.11419232871308316, -1.4043506729214543, -0.37020568373016016, -0.8164509317287046, -1.2089030449946845, 0.40325251252427163, 0.5988905170317518, -0.2931640988477134, -1.5510853302857561, -0.24183759342848976, 0.7037944665127933, 1.3189794198774971, 2.429820860571282, 1.415736109948955, -0.5394801247020993, -0.1389648905335894, -0.19298354662922473, -2.4347759605727455, -0.28459499791082354, 2.1718476532440136, 1.7581883718188507, 2.3930072308949697, 1.2782706312149434, -0.7723818445283142, -3.1069995231149807, -1.490703721482761, -0.49933456746415633, 0.36898174355184643, 1.2377212105266058, 2.2592952497193295, 2.415462371757225, 1.5002192983066758, 0.3556344750826511, -0.582707855083937]

# %%
plt.figure(figsize=(10,5))
plt.plot(ar2_b,'-o')
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
# AR(2) Bagian C
# phi1 = 1 dan phi2 = -0.25
np.random.seed(160)

psi1, psi2 = 1, -0.25

# Membuat 2 nilai awal
ar2_c = [
    np.random.uniform(0, 1),
    np.random.uniform(0, 1)
]

# Membentuk total 100 observasi
for i in range(98):
    ar2_c.append(
        psi1 * ar2_c[i+1] +
        psi2 * ar2_c[i] +
        np.random.normal(0, 1)
    )

print(ar2_c)
# Out:
# [0.8333928248007452, 0.32343457490346217, -1.3915439499050348, -2.408356681865201, -0.291931886409625, 0.9031894052724532, 0.58174765901925, -0.8208326209187485, 0.10530080966459432, -0.5929408538257822, -1.2177262693497046, -1.199708204818652, -2.9008996340681277, -0.32547232932254566, 0.23264955414814753, -1.3151634361496773, -1.3485645251881864, -0.5345211637310867, 0.11278602359477513, 1.6270889642346915, 0.27899542291392176, 1.5221651002409855, 3.3489497638009147, 3.8981095145564804, 2.8846629013786322, 0.6300270989402985, -0.23603989033209136, 0.7165836038156919, -0.3459249337136745, -0.06946223378076916, -0.3114125085351102, -2.0376955483958317, -1.116929806710309, 0.31151403263771005, -0.1006746654667312, -0.046084470421703966, -0.784812842138587, 0.42564312159240647, -0.4367344653155948, -1.620889993056942, -1.4917009414311382, -0.7447650762459324, 1.1450890950463155, 1.0214346577536497, 1.5546158438727655, 1.2062635605893002, 0.8880572343798054, 1.0934139066425104, -0.16381184297637774, 0.012633058379493134, -0.3393168505710193, -0.8585153911216147, -0.3602803144245028, -1.136169228304844, -2.0094195745547365, -2.0377865038250866, 0.03421922888154638, -1.0687273034965479, 0.8714672351342316, 2.0207600374145414, 1.9267906272083661, 1.8842480452730557, 1.8840324765509515, 2.995539640967438, 3.3424376947512973, 3.055929078500926, 1.4774366100730956, -0.22083698762717086, 0.0643130986372149, -0.7703619916174405, -1.4755565334074403, -0.17714897216497127, 0.1859655325767658, -0.4112660828724507, -1.6392470929086753, -0.6882451926166637, 0.21896790962322676, 1.1217033794131723, 2.6834963142987234, 2.3261857889352977, 0.6614847183396217, 0.6995175015860211, 0.31051641209655817, -2.1891424865341715, -0.7735305036968814, 1.5503550294706063, 1.8018915378029612, 3.0316306457771445, 2.504220062324833, 0.6134793906647675, -2.22072110683145, -1.7276404947762458, -1.3305168751992142, -0.5278000127258793, 0.6409804670706062, 2.1961802479644126, 3.06635636829614, 2.770757638223626, 1.8385041404415419, 0.6714358440663789]

# %%
plt.figure(figsize=(10,5))
plt.plot(ar2_c,'-o')
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %%
# AR(2) Bagian D
# psi1 = 0.5 dan psi2 = -0.75
np.random.seed(160)

psi1, psi2 = 0.5, -0.75

# Membuat 2 nilai awal
ar2_d = [
    np.random.uniform(0, 1),
    np.random.uniform(0, 1)
]

# Membentuk total 100 observasi
for i in range(98):
    ar2_d.append(
        psi1 * ar2_d[i+1] +
        psi2 * ar2_d[i] +
        np.random.normal(0, 1)
    )

print(ar2_d)
# Out:
# [0.8333928248007452, 0.32343457490346217, -1.9699576497571387, -2.1635088442904666, 2.1642526231519383, 3.297790066009597, -0.3687191522147647, -3.8344850542344653, -0.5691328176180037, 1.6878475631467837, 0.6723131816791209, -1.0599462304459202, -3.0398309980692026, 1.5505444273407578, 2.888042437175942, -1.3480681745460585, -2.815304615656458, 0.08865132550099503, 2.465970180521656, 2.5471692458422264, -1.8957900478922047, -1.2083300399420354, 2.7142110352365454, 3.193054073390611, -0.615340411959723, -3.982569184822033, -1.674680547368956, 3.259716883814905, 1.7643503423217806, -1.10700389081346, -2.205196210330825, -2.015993785361231, 1.4888128796192484, 3.1754217310796085, -0.22031994395665067, -2.3592575670835765, -1.7782858636578662, 2.079235089609317, 1.3147511451054101, -1.9797954919975282, -1.9559556695309166, 0.8485821511536583, 3.4081867636594803, 0.7578110621103475, -1.3577810818087421, -1.3402424563321846, 0.41866221794916086, 1.721435513633749, -0.48849034766893307, -1.08552343104328, -0.5692968244645471, 0.013453885094464324, 0.8471054249499996, -0.5770554630065932, -1.8871772250718148, -0.8232062516275238, 2.573430632058048, 0.2917268464153009, 0.1645397950152807, 0.7455857391023373, 0.37328542186709057, 0.09010083402511737, 0.24656843869222828, 1.6382777695620268, 1.452118728683439, -0.040272668838312264, -1.8521084256717415, -1.8301410392821715, 1.12852003839538, 1.0469814614978707, -1.0120155651782956, -0.18542681537444206, 0.6605236375863777, -0.17218692816643894, -1.7629758191650358, 0.09583766611621025, 1.8675520264446037, 1.5925719352709238, 1.0121568600933668, -0.7652352019166418, -2.1355622380493413, 0.12572451289303455, 1.4409040250789658, -1.6986208953645172, -0.43674738063005325, 2.832191892742306, 1.8018103642518275, 0.39408912791101924, -1.231250908234932, -2.04402531026651, -2.3067199558720652, 1.0261094644852458, 2.085038042015841, 0.6437436614232597, -0.405755439803569, 0.7375643117431074, 1.7035199728236097, 0.5520330845230638, -1.1672878430642246, -1.4720476217436664]

# %%
plt.figure(figsize=(10,5))
plt.plot(ar2_d,'-o')
plt.xlabel('Waktu'), plt.ylabel(r'$Y_t$')
plt.show()

# %% [markdown]
# Membuat plot ACF dan PACF dari masing-masing deret hasil simulasi yang peroleh pada nomor 10. Berdasarkan plot ACF dan PACF tersebut apa yang dapat disimpulkan terkait nilai autokorelasi pada deret AR(2)? (Hint: Identifikasi pola nilai autokorelasi ataupun autokorelasi parsial berdasarkan nilai parameter AR.)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

# Membuat frame 4 baris x 2 kolom
fig, axes = plt.subplots(4, 2, figsize=(12, 16))

# =====================
# a. phi1 = 1.5, phi2 = -0.5
# =====================

plot_acf(ar2_a, lags=20, ax=axes[0, 0])
axes[0, 0].set_title("ACF AR(2): φ₁ = 1.5, φ₂ = -0.5")

plot_pacf(ar2_a, lags=20, ax=axes[0, 1], method="ywm")
axes[0, 1].set_title("PACF AR(2): φ₁ = 1.5, φ₂ = -0.5")


# =====================
# b. phi1 = 0.75, phi2 = -0.25
# =====================

plot_acf(ar2_b, lags=20, ax=axes[1, 0])
axes[1, 0].set_title("ACF AR(2): φ₁ = 0.75, φ₂ = -0.25")

plot_pacf(ar2_b, lags=20, ax=axes[1, 1], method="ywm")
axes[1, 1].set_title("PACF AR(2): φ₁ = 0.75, φ₂ = -0.25")


# =====================
# c. phi1 = 1, phi2 = -0.25
# =====================

plot_acf(ar2_c, lags=20, ax=axes[2, 0])
axes[2, 0].set_title("ACF AR(2): φ₁ = 1, φ₂ = -0.25")

plot_pacf(ar2_c, lags=20, ax=axes[2, 1], method="ywm")
axes[2, 1].set_title("PACF AR(2): φ₁ = 1, φ₂ = -0.25")


# =====================
# d. phi1 = 0.5, phi2 = -0.75
# =====================

plot_acf(ar2_d, lags=20, ax=axes[3, 0])
axes[3, 0].set_title("ACF AR(2): φ₁ = 0.5, φ₂ = -0.75")

plot_pacf(ar2_d, lags=20, ax=axes[3, 1], method="ywm")
axes[3, 1].set_title("PACF AR(2): φ₁ = 0.5, φ₂ = -0.75")


# Merapikan tampilan
plt.tight_layout()

plt.show()

# %% [markdown]
# a. $\phi_1 = 1.5$ dan $\phi_2 = -0.5$
#
# Model yang disarankan adalah **AR(2)**. Hal ini dikarenakan pada plot ACF, nilai autokorelasi tidak langsung terputus, tetapi menurun secara bertahap (*tailing off*). Sementara itu, pada plot PACF, nilai autokorelasi parsial yang paling menonjol terdapat pada lag awal, kemudian nilai pada lag berikutnya cenderung mendekati nol. Pola tersebut merupakan karakteristik model AR(2).
#
# Namun, pada deret ini ACF menurun sangat lambat, sehingga perlu diperhatikan bahwa deretnya memiliki indikasi tidak stasioner atau berada pada batas stasioneritas.
#
# ---
#
# b. $\phi_1 = 0.75$ dan $\phi_2 = -0.25$
#
# Model yang disarankan adalah **AR(2)**. Pada plot ACF, nilai autokorelasi tidak langsung menjadi nol setelah lag tertentu, tetapi menunjukkan pola yang menurun secara bertahap. Sementara itu, pada plot PACF, autokorelasi parsial yang terlihat terutama terdapat pada lag awal, sedangkan lag berikutnya cenderung berada di dalam interval kepercayaan. Pola tersebut sesuai dengan karakteristik model AR(2).
#
# ---
#
# c. $\phi_1 = 1$ dan $\phi_2 = -0.25$
#
# Model yang disarankan adalah **AR(2)**. Plot ACF menunjukkan pola autokorelasi yang menurun secara bertahap dan tidak langsung *cut off*. Sementara itu, pada plot PACF, nilai autokorelasi parsial yang menonjol terdapat pada lag awal, kemudian nilai pada lag berikutnya cenderung mendekati nol. Oleh karena itu, pola tersebut sesuai dengan karakteristik model AR(2).
#
# ---
#
# d. $\phi_1 = 0.5$ dan $\phi_2 = -0.75$
#
# Model yang disarankan adalah **AR(2)**. Pada plot ACF terlihat pola autokorelasi yang berfluktuasi dan tidak langsung terputus setelah lag tertentu. Sementara itu, pada plot PACF, autokorelasi parsial yang dominan terlihat pada lag awal, sedangkan nilai pada lag berikutnya cenderung mendekati nol. Oleh karena itu, deret ini sesuai dengan karakteristik model AR(2).
#
# ---
#
# ### Kesimpulan
#
# Berdasarkan pola ACF dan PACF, keempat deret lebih sesuai dimodelkan sebagai **AR(2)**. Hal ini ditunjukkan oleh pola ACF yang secara umum mengalami *tailing off*, sedangkan PACF menunjukkan autokorelasi parsial yang dominan pada lag awal dan kemudian cenderung mendekati nol. Perbedaan nilai parameter $\phi_1$ dan $\phi_2$ menyebabkan pola ACF dan PACF yang berbeda pada masing-masing deret.
